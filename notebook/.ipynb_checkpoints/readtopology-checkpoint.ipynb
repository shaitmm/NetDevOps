# %%
FILE_NAME="./topology/netdevops.unl"

# %%
from collections import defaultdict

import netaddr
from lxml import etree

# %%
def get_topology(top_file):
    networks = defaultdict(list)
    
    #用lxml etree 解析 XML 文件
    top = etree.parse(top_file)
    
    # 在XML 中的interface tag
    for interface in top.xpath("//interface"):
        # 当前 interface 的 的network ID 值
        network_id = interface.xpath("@network_id")[0]
        
        # 当前 interface 的父节点的名称，即node的名称
        node_name = interface.xpath("../@name")[0]
        
        #当前interface 节点的接口名称
        interface_name = interface.xpath("@name")[0]
        networks[network_id].append((node_name,interface_name))
    return networks

# %%
class Interface_ip():
    def __init__(self, ipnetwork, prefixlen=30):
        self.ip = netaddr.IPNetwork(ipnetwork)
        self.ip = self.ip.subnet(prefixlen)
        
    def get(self):
        ips = self.ip.send(None)
        return [str(ip) for ip in ips.iter_hosts()]

# %%
a = get_topology(FILE_NAME)

# %%
a
# Out:
# defaultdict(list,
#             {'1': [('xrv1', 'Gi0/0/0/0'), ('xrv2', 'Gi0/0/0/0')],
#              '10': [('xrv11', 'Gi0/0/0/1'), ('xrv13', 'Gi0/0/0/0')],
#              '11': [('xrv12', 'Gi0/0/0/1'), ('xrv13', 'Gi0/0/0/1')],
#              '12': [('xrv6', 'Gi0/0/0/0'), ('xrv7', 'Gi0/0/0/0')],
#              '13': [('xrv6', 'Gi0/0/0/1'), ('xrv8', 'Gi0/0/0/1')],
#              '14': [('xrv7', 'Gi0/0/0/1'), ('xrv9', 'Gi0/0/0/1')],
#              '15': [('xrv8', 'Gi0/0/0/2'), ('xrv10', 'Gi0/0/0/2')],
#              '16': [('xrv9', 'Gi0/0/0/2'), ('xrv11', 'Gi0/0/0/2')],
#              '17': [('xrv8', 'Gi0/0/0/0'), ('xrv9', 'Gi0/0/0/0')],
#              '18': [('xrv1', 'Gi0/0/0/4'), ('xrv6', 'Gi0/0/0/2')],
#              '19': [('xrv1', 'Gi0/0/0/5'), ('xrv7', 'Gi0/0/0/2')],
#              '2': [('xrv1', 'Gi0/0/0/1'), ('xrv3', 'Gi0/0/0/0')],
#              '20': [('xrv2', 'Gi0/0/0/4'), ('xrv6', 'Gi0/0/0/3')],
#              '21': [('xrv2', 'Gi0/0/0/5'), ('xrv7', 'Gi0/0/0/3')],
#              '22': [('xrv6', 'Gi0/0/0/4'), ('xrv14', 'Gi0/0/0/0')],
#              '23': [('xrv8', 'Gi0/0/0/3'), ('xrv15', 'Gi0/0/0/0')],
#              '24': [('xrv3', 'Gi0/0/0/6'), ('vIOS16', 'Gi0/0')],
#              '25': [('xrv4', 'Gi0/0/0/6'), ('vIOS17', 'Gi0/0')],
#              '26': [('xrv5', 'Gi0/0/0/6'), ('vIOS18', 'Gi0/0')],
#              '27': [('xrv12', 'Gi0/0/0/6'), ('vIOS19', 'Gi0/0')],
#              '28': [('xrv12', 'Gi0/0/0/7'), ('vIOS20', 'Gi0/0')],
#              '29': [('xrv13', 'Gi0/0/0/6'), ('vIOS21', 'Gi0/0')],
#              '3': [('xrv1', 'Gi0/0/0/2'), ('xrv4', 'Gi0/0/0/0')],
#              '30': [('xrv13', 'Gi0/0/0/7'), ('vIOS20', 'Gi0/1')],
#              '31': [('xrv3', 'Gi0/0/0/7'), ('vIOS17', 'Gi0/1')],
#              '32': [('xrv5', 'Gi0/0/0/7'), ('vIOS17', 'Gi0/2')],
#              '33': [('xrv6', 'Mgmt0/0/CPU0/0'),
#               ('xrv8', 'Mgmt0/0/CPU0/0'),
#               ('xrv14', 'Mgmt0/0/CPU0/0'),
#               ('xrv15', 'Mgmt0/0/CPU0/0')],
#              '34': [('xrv2', 'Mgmt0/0/CPU0/0'),
#               ('xrv5', 'Mgmt0/0/CPU0/0'),
#               ('xrv7', 'Mgmt0/0/CPU0/0'),
#               ('xrv9', 'Mgmt0/0/CPU0/0'),
#               ('xrv11', 'Mgmt0/0/CPU0/0'),
#               ('xrv13', 'Mgmt0/0/CPU0/0'),
#               ('vIOS18', 'Gi0/3'),
#               ('vIOS21', 'Gi0/3')],
#              '35': [('xrv1', 'Mgmt0/0/CPU0/0'),
#               ('xrv3', 'Mgmt0/0/CPU0/0'),
#               ('vIOS16', 'Gi0/3'),
#               ('VRR-Linux22', 'e0')],
#              '36': [('xrv10', 'Mgmt0/0/CPU0/0'),
#               ('xrv12', 'Mgmt0/0/CPU0/0'),
#               ('vIOS19', 'Gi0/3'),
#               ('VRR-Linux23', 'e0')],
#              '37': [('xrv4', 'Mgmt0/0/CPU0/0'), ('vIOS17', 'Gi0/3')],
#              '38': [('vIOS20', 'Gi0/3')],
#              '39': [('MGT_Linux24', 'e0'),
#               ('MGT_Linux25', 'e0'),
#               ('MGT_Linux26', 'e0'),
#               ('MGT_Linux27', 'e0'),
#               ('MGT_Linux28', 'e0'),
#               ('MGT_Linux29', 'e0'),
#               ('MGT_Linux30', 'e0'),
#               ('MGT_Linux31', 'e0'),
#               ('LAB_MGT', 'e0')],
#              '4': [('xrv1', 'Gi0/0/0/3'), ('xrv5', 'Gi0/0/0/0')],
#              '40': [('xrv1', 'Gi0/0/0/6'), ('VRR-Linux22', 'e1')],
#              '41': [('xrv10', 'Gi0/0/0/3'), ('VRR-Linux23', 'e1')],
#              '5': [('xrv2', 'Gi0/0/0/1'), ('xrv3', 'Gi0/0/0/1')],
#              '6': [('xrv2', 'Gi0/0/0/2'), ('xrv4', 'Gi0/0/0/1')],
#              '7': [('xrv2', 'Gi0/0/0/3'), ('xrv5', 'Gi0/0/0/1')],
#              '8': [('xrv10', 'Gi0/0/0/0'), ('xrv11', 'Gi0/0/0/0')],
#              '9': [('xrv10', 'Gi0/0/0/1'), ('xrv12', 'Gi0/0/0/0')]})

# %%
def make_xrv_cfg(ipnetwork, topology):
    ips = Interface_ip(ipnetwork)
    
    inf_cfg_tmp = '''
interface {interface_name}
 ipv4 address {ip_address} 255.255.255.252
 no shutdown
    '''
    for network_id, network in topology.items():
        # 确认有2个节点
        if len(network) == 2:
            # 确认 两边都是xrv
            if 'xrv' in network[0][0] and 'xrv' in network[1][0]:
                (ip1, ip2) = ips.get()
                # 生成第一个node 的配置：
                print(network[0][0], ":")
                print(inf_cfg_tmp.format(interface_name=network[0][1],ip_address=ip1))
                print(network[1][0], ":")
                print(inf_cfg_tmp.format(interface_name=network[1][1],ip_address=ip2))

# %%
make_xrv_cfg("10.10.0.0/16", get_topology(FILE_NAME))
# Out:
# xrv8 :
#
# interface Gi0/0/0/0
#  ipv4 address 10.10.0.1 255.255.255.252
#  no shutdown
#
# xrv9 :
#
# interface Gi0/0/0/0
#  ipv4 address 10.10.0.2 255.255.255.252
#  no shutdown
#
# xrv2 :
#
# interface Gi0/0/0/1
#  ipv4 address 10.10.0.5 255.255.255.252
#  no shutdown
#
# xrv3 :
#
# interface Gi0/0/0/1
#  ipv4 address 10.10.0.6 255.255.255.252
#  no shutdown
#
# xrv6 :
#
# interface Gi0/0/0/0
#  ipv4 address 10.10.0.9 255.255.255.252
#  no shutdown
#
# xrv7 :
#
# interface Gi0/0/0/0
#  ipv4 address 10.10.0.10 255.255.255.252
#  no shutdown
#
# xrv2 :
#
# interface Gi0/0/0/2
#  ipv4 address 10.10.0.13 255.255.255.252
#  no shutdown
#
# xrv4 :
#
# interface Gi0/0/0/1
#  ipv4 address 10.10.0.14 255.255.255.252
#  no shutdown
#
# xrv2 :
#
# interface Gi0/0/0/5
#  ipv4 address 10.10.0.17 255.255.255.252
#  no shutdown
#
# xrv7 :
#
# interface Gi0/0/0/3
#  ipv4 address 10.10.0.18 255.255.255.252
#  no shutdown
#
# xrv11 :
#
# interface Gi0/0/0/1
#  ipv4 address 10.10.0.21 255.255.255.252
#  no shutdown
#
# xrv13 :
#
# interface Gi0/0/0/0
#  ipv4 address 10.10.0.22 255.255.255.252
#  no shutdown
#
# xrv1 :
#
# interface Gi0/0/0/1
#  ipv4 address 10.10.0.25 255.255.255.252
#  no shutdown
#
# xrv3 :
#
# interface Gi0/0/0/0
#  ipv4 address 10.10.0.26 255.255.255.252
#  no shutdown
#
# xrv6 :
#
# interface Gi0/0/0/4
#  ipv4 address 10.10.0.29 255.255.255.252
#  no shutdown
#
# xrv14 :
#
# interface Gi0/0/0/0
#  ipv4 address 10.10.0.30 255.255.255.252
#  no shutdown
#
# xrv10 :
#
# interface Gi0/0/0/0
#  ipv4 address 10.10.0.33 255.255.255.252
#  no shutdown
#
# xrv11 :
#
# interface Gi0/0/0/0
#  ipv4 address 10.10.0.34 255.255.255.252
#  no shutdown
#
# xrv12 :
#
# interface Gi0/0/0/1
#  ipv4 address 10.10.0.37 255.255.255.252
#  no shutdown
#
# xrv13 :
#
# interface Gi0/0/0/1
#  ipv4 address 10.10.0.38 255.255.255.252
#  no shutdown
#
# xrv1 :
#
# interface Gi0/0/0/2
#  ipv4 address 10.10.0.41 255.255.255.252
#  no shutdown
#
# xrv4 :
#
# interface Gi0/0/0/0
#  ipv4 address 10.10.0.42 255.255.255.252
#  no shutdown
#
# xrv8 :
#
# interface Gi0/0/0/3
#  ipv4 address 10.10.0.45 255.255.255.252
#  no shutdown
#
# xrv15 :
#
# interface Gi0/0/0/0
#  ipv4 address 10.10.0.46 255.255.255.252
#  no shutdown
#
# xrv1 :
#
# interface Gi0/0/0/0
#  ipv4 address 10.10.0.49 255.255.255.252
#  no shutdown
#
# xrv2 :
#
# interface Gi0/0/0/0
#  ipv4 address 10.10.0.50 255.255.255.252
#  no shutdown
#
# xrv1 :
#
# interface Gi0/0/0/5
#  ipv4 address 10.10.0.53 255.255.255.252
#  no shutdown
#
# xrv7 :
#
# interface Gi0/0/0/2
#  ipv4 address 10.10.0.54 255.255.255.252
#  no shutdown
#
# xrv2 :
#
# interface Gi0/0/0/3
#  ipv4 address 10.10.0.57 255.255.255.252
#  no shutdown
#
# xrv5 :
#
# interface Gi0/0/0/1
#  ipv4 address 10.10.0.58 255.255.255.252
#  no shutdown
#
# xrv1 :
#
# interface Gi0/0/0/3
#  ipv4 address 10.10.0.61 255.255.255.252
#  no shutdown
#
# xrv5 :
#
# interface Gi0/0/0/0
#  ipv4 address 10.10.0.62 255.255.255.252
#  no shutdown
#
# xrv6 :
#
# interface Gi0/0/0/1
#  ipv4 address 10.10.0.65 255.255.255.252
#  no shutdown
#
# xrv8 :
#
# interface Gi0/0/0/1
#  ipv4 address 10.10.0.66 255.255.255.252
#  no shutdown
#
# xrv1 :
#
# interface Gi0/0/0/4
#  ipv4 address 10.10.0.69 255.255.255.252
#  no shutdown
#
# xrv6 :
#
# interface Gi0/0/0/2
#  ipv4 address 10.10.0.70 255.255.255.252
#  no shutdown
#
# xrv10 :
#
# interface Gi0/0/0/1
#  ipv4 address 10.10.0.73 255.255.255.252
#  no shutdown
#
# xrv12 :
#
# interface Gi0/0/0/0
#  ipv4 address 10.10.0.74 255.255.255.252
#  no shutdown
#
# xrv9 :
#
# interface Gi0/0/0/2
#  ipv4 address 10.10.0.77 255.255.255.252
#  no shutdown
#
# xrv11 :
#
# interface Gi0/0/0/2
#  ipv4 address 10.10.0.78 255.255.255.252
#  no shutdown
#
# xrv7 :
#
# interface Gi0/0/0/1
#  ipv4 address 10.10.0.81 255.255.255.252
#  no shutdown
#
# xrv9 :
#
# interface Gi0/0/0/1
#  ipv4 address 10.10.0.82 255.255.255.252
#  no shutdown
#
# xrv2 :
#
# interface Gi0/0/0/4
#  ipv4 address 10.10.0.85 255.255.255.252
#  no shutdown
#
# xrv6 :
#
# interface Gi0/0/0/3
#  ipv4 address 10.10.0.86 255.255.255.252
#  no shutdown
#
# xrv8 :
#
# interface Gi0/0/0/2
#  ipv4 address 10.10.0.89 255.255.255.252
#  no shutdown
#
# xrv10 :
#
# interface Gi0/0/0/2
#  ipv4 address 10.10.0.90 255.255.255.252
#  no shutdown
